# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
df=pd.read_csv("HousingDataset.csv")

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df=df.fillna({"Bedroom2":0,"Bathroom":0,"Car":0})
df["Landsize"]=df["Landsize"].fillna(df["Landsize"].mean())

# %%
df["Distance"]=df["Distance"].fillna(df["Distance"].mean())
df["YearBuilt"]=df["YearBuilt"].fillna(df["YearBuilt"].mean())
df["Lattitude"]=df["Lattitude"].fillna(df["Lattitude"].mean())
df["Longtitude"]=df["Longtitude"].fillna(df["Longtitude"].mean())
df["Propertycount"]=df["Propertycount"].fillna(df["Propertycount"].mean())

# %%
df.drop("Postcode",inplace=True,axis=1)

# %%
df.head()
df.drop(["Suburb","Address","Type","Method","SellerG","Date","BuildingArea","YearBuilt","CouncilArea","Regionname"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Rooms               0
# Price            7610
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# Lattitude           0
# Longtitude          0
# Propertycount       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
X=df.drop("Price",axis=1)
Y=df.Price
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
df
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car    Landsize  \
# 1          2  1480000.0       2.5       2.0       1.0  1.0  202.000000
# 2          2  1035000.0       2.5       2.0       1.0  0.0  156.000000
# 4          3  1465000.0       2.5       3.0       2.0  0.0  134.000000
# 5          3   850000.0       2.5       3.0       2.0  1.0   94.000000
# 6          4  1600000.0       2.5       3.0       1.0  2.0  120.000000
# ...      ...        ...       ...       ...       ...  ...         ...
# 34852      4  1480000.0       6.3       4.0       1.0  3.0  593.000000
# 34853      2   888000.0       6.3       2.0       2.0  1.0   98.000000
# 34854      2   705000.0       6.3       2.0       1.0  2.0  220.000000
# 34855      3  1140000.0       6.3       0.0       0.0  0.0  593.598993
# 34856      2  1020000.0       6.3       2.0       1.0  0.0  250.000000
#
#        Lattitude  Longtitude  Propertycount
# 1     -37.799600  144.998400         4019.0
# ...

# %%
model1=LinearRegression()

# %%
model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model1.predict(X_test)
# Out:
# array([ 657178.68713191, 1828374.37175289,  986736.74645299, ...,
#        1535429.7425034 , 1545331.89266738,  896253.15011936],
#       shape=(5450,))

# %%
model1.score(X_test,Y_test)
# Out:
# 0.44179646147974894

# %%
model1.score(X_train,Y_train)
# Out:
# 0.4408202816475958

# %%
model2=Lasso()

# %%
model2.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
model2.predict(X_test)
# Out:
# array([ 657194.30557391, 1828352.13359749,  986734.04689306, ...,
#        1535418.24021921, 1545319.75611931,  896251.59475911],
#       shape=(5450,))

# %%
model2.score(X_test,Y_test)
# Out:
# 0.4063089507845581

# %%
model2.score(X_train,Y_train)
# Out:
# 0.4408202811599191

# %%
model3=Ridge()

# %%
model3.fit(X_train,Y_train)
# Out:
# Ridge()

# %%
model3.predict(X_test)
# Out:
# array([ 658145.27733749, 1827176.80625337,  986703.73622486, ...,
#        1535009.41117832, 1544924.50093731,  896272.49420673],
#       shape=(5450,))

# %%
model3.score(X_test,Y_test)
# Out:
# 0.4418038403165161
